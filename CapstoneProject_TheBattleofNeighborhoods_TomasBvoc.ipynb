# %%
print("Coffee places in Bratislava")
# Out:
# Coffee places in Bratislava

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
# connect with Foursquare
CLIENT_ID = 'RJ0L4M3BD4EYF0C52KN4QFTVIFYUZTFBN3O0AOXYE2PDNWIM' # your Foursquare ID
CLIENT_SECRET = 'MK3CN2JDNEFX43W3XWQQ50HZX5BOVSS0WBXG13XH3YIMC4MV' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RJ0L4M3BD4EYF0C52KN4QFTVIFYUZTFBN3O0AOXYE2PDNWIM
# CLIENT_SECRET:MK3CN2JDNEFX43W3XWQQ50HZX5BOVSS0WBXG13XH3YIMC4MV

# %%
# define the center of my interested area

address = 'Mileticova 27, Bratislava, SK'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 48.151024 17.139338702160586

# %%
search_query = 'coffee'
radius = 1500
print(search_query + ' .... OK!')
# Out:
# coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RJ0L4M3BD4EYF0C52KN4QFTVIFYUZTFBN3O0AOXYE2PDNWIM&client_secret=MK3CN2JDNEFX43W3XWQQ50HZX5BOVSS0WBXG13XH3YIMC4MV&ll=48.151024,17.139338702160586&v=20180604&query=coffee&radius=1500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f2025dc40ea3c7ec7b9aea5'},
#  'response': {'venues': [{'id': '4ee8549ed3e31fdba19e2bd9',
#     'name': 'Urban Coffee',
#     'location': {'address': 'Plynárenská 1',
#      'crossStreet': 'Prievozská',
#      'lat': 48.146523,
#      'lng': 17.143003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.146523,
#        'lng': 17.143003}],
#      'distance': 570,
#      'postalCode': '821 08',
#      'cc': 'SK',
#      'city': 'Bratislava',
#      'state': 'Bratislavský kraj',
#      'country': 'Slovensko',
#      'formattedAddress': ['Plynárenská 1 (Prievozská)',
#       '821 08 Bratislava',
#       'Slovensko']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '39428969'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                name  \
# 0  4ee8549ed3e31fdba19e2bd9        Urban Coffee
# 1  4c0bc9fe340720a141968893        MEM'S Coffee
# 2  56efda9acd106dcecacf0353        Coffee Break
# 3  4b977cc0f964a520a70535e3      Steam & Coffee
# 4  4bc7080f15a7ef3b609878da  Coffeeshop Company
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1595942968    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1595942968    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1595942968    False
# 3  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1595942968    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1595942968    False
#
# ...

# %%
# next

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name          categories  \
# 0                        Urban Coffee                Café
# 1                        MEM'S Coffee                Café
# 2                        Coffee Break                Café
# 3                      Steam & Coffee      Breakfast Spot
# 4                  Coffeeshop Company                Café
# 5                              Coffee                Café
# 6                     McFood & Coffee          Restaurant
# 7              Timi Amo Gelato&Coffee           Cafeteria
# 8             Black Coffee SC Central                Café
# 9                        Snake coffee                Café
# 10                    Coffee Brothers         Coffee Shop
# 11                       Polar Coffee                Café
# 12  Mercek Cafe Coffee shop&Chocolate         Coffee Shop
# 13         Good Times coffee roasters                Café
# 14                       Power Coffee                Café
# ...

# %%
dataframe_filtered.name
# Out:
# 0                          Urban Coffee
# 1                          MEM'S Coffee
# 2                          Coffee Break
# 3                        Steam & Coffee
# 4                    Coffeeshop Company
# 5                                Coffee
# 6                       McFood & Coffee
# 7                Timi Amo Gelato&Coffee
# 8               Black Coffee SC Central
# 9                          Snake coffee
# 10                      Coffee Brothers
# 11                         Polar Coffee
# 12    Mercek Cafe Coffee shop&Chocolate
# 13           Good Times coffee roasters
# 14                         Power Coffee
# 15                         Power Coffee
# 16                     Photo Art Coffee
# 17                         Coffee Beans
# 18                          Coffee Noir
# 19                         urban coffee
# 20                      Coffee Zone 2st
# 21                      Zastávka Coffee
# 22                        Cartel Coffee
# ...

# %%
# display map of coffee places in Bratislava

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around my living place

# add a red circle marker to represent the Mileticova 27
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='my living place',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffe places blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat,lng],  
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins
from folium.plugins import HeatMap


dataframe_filtered['lat'] = dataframe_filtered['lat'].astype(float)
dataframe_filtered['lng'] = dataframe_filtered['lng'].astype(float)

dataframe_filtered = dataframe_filtered.dropna(axis=0, subset=['lat','lng'])

heat_data = [[row['lat'],row['lng']] for index, row in dataframe_filtered.iterrows()]
HeatMap(heat_data).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitudeNew = 48.146051
longitudeNew = 17.131415

# %%
folium.features.CircleMarker(
    [latitudeNew, longitudeNew],
    radius=18,
    color='green',
    popup='my new coffee place',
    fill = True,
    fill_color = 'green',
    fill_opacity = 0.4
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
